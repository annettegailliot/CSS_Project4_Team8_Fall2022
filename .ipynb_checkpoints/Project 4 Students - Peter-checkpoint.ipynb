# %% [markdown]
# # [Computational Social Science] Project 4: Unsupervised Learning
#
# Group Number:
#
# Group Members:

# %% [markdown]
# ## Data Description and Preprocessing
#
# For this project, you will explore data from the [National Health and Nutrition Examination Survey](https://www.kaggle.com/cdc/national-health-and-nutrition-examination-survey?select=questionnaire.csv). NHANES is a unique study that combines survey methodology with in-person medical examinations to create a dataset with demographic information, health indicators, and health outcomes.

# %% [markdown]
# We start by importing the data and doing some preliminary preprocessing for you. We import some libraries that will be helpful as well. 'SEQN' is the ID number for each respondent, and 'HSD010' will be our target outcome. [HSD010](https://wwwn.cdc.gov/Nchs/Nhanes/2013-2014/HSQ_H.htm#HSD010) asks for the respondent's self reported health condition, which can range from "excellent" to "poor."

# %%
! pip install keras
! pip install tensorflow
# Out:
# Requirement already satisfied: keras in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (2.11.0)
# WARNING: You are using pip version 21.1.3; however, version 22.3.1 is available.
# You should consider upgrading via the 'c:\users\peteramerkhanian\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: tensorflow in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (2.11.0)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.19.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.3.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.28.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.51.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.4.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.7.0)
# Requirement already satisfied: packaging in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (21.3)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.2.0)
# Requirement already satisfied: setuptools in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (56.0.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.14.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.1.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.6.3)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (4.0.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (22.12.6)
# Requirement already satisfied: six>=1.12.0 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.21.4)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (14.0.6)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.15.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.26.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.8.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.2.8)
# WARNING: You are using pip version 21.1.3; however, version 22.3.1 is available.
# You should consider upgrading via the 'c:\users\peteramerkhanian\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (5.1.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.26.7)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.2.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\peteramerkhanian\appdata\local\programs\python\python39\lib\site-packages (from packaging->tensorflow-intel==2.11.0->tensorflow) (3.0.6)

# %%
# Import libraries
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.model_selection import train_test_split
sns.set_style("darkgrid")
from sklearn.model_selection import train_test_split

# %%
# Load nhanes data
nhanes = pd.read_csv('nhanes.csv')
# Get the ID numbers for each observation (seqn)
seqn = nhanes['SEQN']
# Get the target, "self-reported health condition," HSD010
hsd010 = nhanes['HSD010']
# Drop SEQN from the dataframe and then apply the standard scaler
nhanes = nhanes.drop(['SEQN', 'HSD010'], axis = 1)
nhanes_scaled = pd.DataFrame(StandardScaler().fit_transform(nhanes),
                             columns = nhanes.columns)
# Add the ID and target back in
nhanes_scaled['SEQN'] = seqn
nhanes_scaled['HSD010'] = hsd010
nhanes_scaled = nhanes_scaled.set_index('SEQN')
nhanes_scaled.head()
# Out:
#        DR1DRSTZ  DR1EXMER  DRABF    DRDINT   DR1DBIH    DR1DAY   DR1LANG  \
# SEQN
# 73568       0.0  2.034312    0.0  0.324834 -0.393906  1.085853 -0.194202
# 73576       0.0  0.261930    0.0 -3.078499  0.568251  0.634362 -0.194202
# 73579       0.0  0.728346    0.0  0.324834  1.530407 -1.623092 -0.194202
# 73581       0.0 -0.857470    0.0  0.324834  0.480782  1.085853 -0.194202
# 73584       0.0  0.495138    0.0  0.324834  0.305844 -1.623092 -0.194202
#
#        DR1MNRSP  DR1HELPD   DBQ095Z  ...    OHQ770    OHQ845   PAAQUEX  \
# SEQN                                 ...
# 73568 -0.057306  0.128246 -0.189513  ...  0.383802 -0.646584 -0.484200
# 73576 -0.057306  0.128246  0.080373  ...  0.383802 -1.539259 -0.484200
# 73579 -0.057306  0.128246 -0.189513  ...  0.383802 -1.539259  2.065262
# 73581 -0.057306  0.128246  0.080373  ...  0.383802 -0.646584 -0.484200
# 73584 -0.057306  0.128246  0.080373  ... -2.605509  0.246091  2.065262
#
#          SMQ860  SMQ870    SMQ872    SMQ874    SMQ878  SMAQUEX.x  HSD010
# SEQN
# 73568  1.125008     0.0 -2.081666  1.087115  1.463404   0.612440       1
# 73576  1.125008     0.0 -2.081666  1.087115 -0.683338  -1.632812       1
# 73579 -0.888883     0.0  0.480384 -0.919866 -0.683338  -1.632812       2
# 73581  1.125008     0.0  0.480384 -0.919866 -0.683338   0.612440       2
# 73584  1.125008     0.0  0.480384 -0.919866  1.463404  -1.632812       3
#
# [5 rows x 242 columns]

# %% [markdown]
# ## Plots

# %% [markdown]
# Let's take a look at the data. Below we visualize boxplots of family income to federal poverty line ratio ('INDFMPIR') and self-reported health condition. Notice how there are some clear patterns (the lower the ratio, the lower reported health condition), but it's not a perfect separation. We have 240+ features in our dataset, and we likely have several features in our dataset that highly correlate with our family income-poverty line ratio measure - PCA will help us simplify these.

# %%
# Create a binary version of hsd010 where 1-3 are "good" and 4-5 are "poor"
nhanes_scaled['HSD010_binary'] = hsd010_binary = nhanes_scaled['HSD010'].replace(
    [1, 2, 3, 4, 5], ['good', 'good', 'good', 'poor', 'poor']) 
# Recode the original hsd010 with the string labels
nhanes_scaled['HSD010'] = nhanes_scaled['HSD010'].replace(
    [1, 2, 3, 4, 5], ['excellent', 'very good', 'good', 'fair', 'poor'])
# Boxplot of hsd010
ax = sns.boxplot(x = 'HSD010', y = 'INDFMPIR', data = nhanes_scaled)
ax.set(xlabel = "Self Reported Health Condition",
      ylabel = "Family Income to Poverty Line Ratio")
ax.set_title("Boxplot of Family Income to Poverty Line Ratio by Self-Reported Health Status")
plt.show()

# %%
# Boxplot of hsd010_binary
ax = sns.boxplot(x = 'HSD010_binary', y = 'INDFMPIR', data = nhanes_scaled)
ax.set(xlabel = "Self Reported Health Condition",
      ylabel = "Family Income to Poverty Line Ratio")
ax.set_title("Boxplot of Family Income to Poverty Line Ratio by Binary Self-Reported Health Status")
plt.show()

# %% [markdown]
# Family income also is not necessarily well correlated with measured health outcomes. See below where we look at the relationship between Body Mass Index (BMI) and the family income-poverty line ratio, and shade points by self-reported health condition. It's hard to find a clear pattern - this is where clustering may come in handy.

# %%
ax = sns.scatterplot(x = "INDFMPIR", y = "BMXBMI", hue = "HSD010", palette = "tab10", data = nhanes_scaled)
ax.set(xlabel = "Income to Poverty Line Ratio",
      ylabel = "Body Mass Index")
ax.set_title("BMI v. Income-Poverty Ratio")
plt.show()

# %% [markdown]
# Before we move to working on unsupervised methods, we'll drop our target variables again:

# %%
nhanes_scaled = nhanes_scaled.drop(['HSD010', 'HSD010_binary'], axis = 1)

# %% [markdown]
# ## Principal Component Analysis

# %% [markdown]
# Conduct a Principal Component Analysis (PCA) of the nhanes data. The data has already been prepared for you, so you can work directly on nhanes_scaled. Be sure to do the following:
#
# - Choose the number of components and provide 1-2 sentences about your choice of the number of components.
# - Plot a barplot of the variation explained by each component. *Hint*: look at the attributes associated with your model.
# - Choose how many components you will use to fit a supervised learning model and provide 1-2 sentences to explain that choice.
# - Plot a 2D scatterplot of the first two components and provide 1-2 sentences analyzing the plot.

# %% [markdown]
# ### Train PCA and Discuss Number of Components

# %%
n_components = 30
# fitting
pca = PCA(n_components=n_components)
principalComponents_nhanes = pca.fit_transform(nhanes_scaled)

# dataframing
pca_columns = [f"PCA{x+1}" for x in np.arange(0, principalComponents_nhanes.shape[1])]
pca_df = pd.DataFrame(principalComponents_nhanes, columns=pca_columns)

# get a look at the explained variances
pca.explained_variance_ratio_

print(f"Proportion of variance explained with {principalComponents_nhanes.shape[1]} components:", 
      round(np.sum(pca.explained_variance_ratio_), 6))
# Out:
# Proportion of variance explained with 30 components: 0.536285

# %% [markdown]
# ### Barplot of Components

# %%
sns.set_style("whitegrid")
gig, ax = plt.subplots(1, 1, figsize=(16, 6))
p = ax.bar(pca_columns, pca.explained_variance_ratio_)
ax.bar_label(p,
             label_type='edge', labels=[round(var_exp, 3) for var_exp in pca.explained_variance_ratio_],
             c="black",
             fontsize=12,
             padding=1.5,
             rotation=90)
ax.set_ylabel("Proportion Variance Explained")
ax.set_xlabel("Principal Components")
ax.set_title("Proportion of Variance Explained by Each Component", fontsize=16)
ax.set_xticklabels(pca_columns, rotation=90, fontsize=12)
ax.set_ylim(0, .12);
# Out:
# C:\Users\PETERA~2\AppData\Local\Temp/ipykernel_23064/1357715035.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(pca_columns, rotation=90, fontsize=12)

# %% [markdown]
# ### How many components will you use to fit a supervised learning model?

# %% [markdown]
# By using `PCA()`'s built in maximum likelihood estimator for choosing the number of components, I found that the optimal choice was 233 components, which described all of the variance in the original data and drops 8 columns. However, in using PCA, I'm hoping to shrink the data much more, so I opt to instead use **30 components**, which only described 54% of the variance in the data, but is much smaller than the original number of columns and so should have considerable computation advantages.

# %% [markdown]
# ### 2D Scatterplot of the first two components

# %%
sns.set_style("whitegrid")
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
ax.set_xlabel('PCA1',fontsize=20)
ax.set_ylabel('PCA2',fontsize=20)
ax.set_title("Principal Component Analysis of NHANES",fontsize=20)
plotting_df  = pd.concat([pca_df, hsd010], axis=1)
sns.scatterplot(x=plotting_df['PCA1'],
                y=plotting_df['PCA2'],
                hue=plotting_df['HSD010'],
                ax=ax,
                s=100,
                alpha=.7);

# %% [markdown]
# ## K-Means

# %% [markdown]
# - Choose a clustering algorithm and explain it in 1-2 sentences.
# - Cluster the nhanes data. Detail any choice you need to make with regards to number of clusters, and how you arrived at that choice. For instance, you might use the [elbow method](https://en.wikipedia.org/wiki/Elbow_method_(clustering) if you choose k-means.
# - Plot your clusters on top of BMI v. Income Poverty Ratio Plot. Describe what you see in 1-2 sentences.
# - Retrain the clustering algorithm, but this time use your PCA results instead of the original dataframe. Plot the clusters on top of the 2D PCA scatterplot from the previous step. Describe your results in 1-2 sentences.

# %% [markdown]
# ### Choose a Clustering Algorithm

# %%
## Your Answer Here

# %% [markdown]
# ### Cluster nhanes

# %%
## Your Answer Here

# %% [markdown]
# ### Plot your clusters on top of the BMI v. Income Poverty Ratio Plot

# %%
## Your Answer Here

# %% [markdown]
# ## Your Answer Here

# %% [markdown]
# ### Retrain the clustering algorithm on PCA components and plot clusters on your 2D scatter

# %%
## Your Answer Here

# %% [markdown]
# ## Your Answer Here

# %% [markdown]
# ## Neural Network

# %% [markdown]
# Now we are ready to predict! Do the following:
#
# - Choose either HSD010 or HSD010\_binary as your target outcome.
# - Train a neural network using the original features. Much of the code to train a basic neural net has been set up for you, but you will need to fill in a couple of missing pieces.
# - Train a neural network using only your PCA components as features.
# - Train a neural network using your PCA components and the predicted class membership from your clustering algorithm as features.
# - Compare and contrast how well each algorithm did. Which featurization technique would you pick and why?

# %% [markdown]
# Below we provide a template for training a neural network. Use this template for training on the original features, on the PCA components, and the PCA components + the predicted classes from your clusters.

# %% [markdown]
# ### Neural Network on Original Features

# %%
y = hsd010.values.flatten() # either hsd010 or hsd010_binary, may need to convert to numeric if it isn't already 
X = nhanes_scaled # drop out any columns that aren't features

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .25, random_state = 10)

# %%
import keras
from keras.utils import np_utils 

num_classes = len(np.unique(y)) + 1
# convert class vectors to binary class matrices
y_train = np_utils.to_categorical(y_train, num_classes)
y_test = np_utils.to_categorical(y_test, num_classes)
num_classes = y_test.shape[1]

# %%
model = Sequential()

model.add(
    Dense(X_train.shape[1], input_dim=X_train.shape[1], kernel_initializer='normal', activation='relu')
)

model.add(
    Dense(num_classes, kernel_initializer="normal", activation="softmax")
)

## Add any additional layers you wish here

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy', 'AUC'])

model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=30, batch_size=500, verbose=2)
# Out:
# Epoch 1/30
# 4/4 - 1s - loss: 1.8632 - accuracy: 0.1525 - auc: 0.5087 - val_loss: 1.6239 - val_accuracy: 0.3624 - val_auc: 0.7129 - 644ms/epoch - 161ms/step
# Epoch 2/30
# 4/4 - 0s - loss: 1.5036 - accuracy: 0.4167 - auc: 0.7861 - val_loss: 1.4430 - val_accuracy: 0.4302 - val_auc: 0.7963 - 40ms/epoch - 10ms/step
# Epoch 3/30
# 4/4 - 0s - loss: 1.3237 - accuracy: 0.4910 - auc: 0.8385 - val_loss: 1.3636 - val_accuracy: 0.4457 - val_auc: 0.8114 - 47ms/epoch - 12ms/step
# Epoch 4/30
# 4/4 - 0s - loss: 1.2296 - accuracy: 0.5123 - auc: 0.8527 - val_loss: 1.3237 - val_accuracy: 0.4438 - val_auc: 0.8195 - 44ms/epoch - 11ms/step
# Epoch 5/30
# 4/4 - 0s - loss: 1.1727 - accuracy: 0.5304 - auc: 0.8630 - val_loss: 1.2959 - val_accuracy: 0.4438 - val_auc: 0.8259 - 43ms/epoch - 11ms/step
# Epoch 6/30
# 4/4 - 0s - loss: 1.1251 - accuracy: 0.5510 - auc: 0.8730 - val_loss: 1.2761 - val_accuracy: 0.4457 - val_auc: 0.8299 - 40ms/epoch - 10ms/step
# Epoch 7/30
# 4/4 - 0s - loss: 1.0839 - accuracy: 0.5556 - auc: 0.8821 - val_loss: 1.2634 - val_accuracy: 0.4399 - val_auc: 0.8319 - 41ms/epoch - 10ms/step
# Epoch 8/30
# 4/4 - 0s - loss: 1.0475 - accuracy: 0.5769 - auc: 0.8912 - val_loss: 1.2557 - val_accuracy: 0.4477 - val_auc: 0.8331 - 45ms/epoch - 11ms/step
# Epoch 9/30
# 4/4 - 0s - loss: 1.0177 - accuracy: 0.5885 - auc: 0.8993 - val_loss: 1.2495 - val_accuracy: 0.4360 - val_auc: 0.8338 - 43ms/epoch - 11ms/step
# Epoch 10/30
# 4/4 - 0s - loss: 0.9882 - accuracy: 0.6021 - auc: 0.9069 - val_loss: 1.2448 - val_accuracy: 0.4264 - val_auc: 0.8353 - 43ms/epoch - 11ms/step
# Epoch 11/30
# 4/4 - 0s - loss: 0.9627 - accuracy: 0.6156 - auc: 0.9129 - val_loss: 1.2399 - val_accuracy: 0.4360 - val_auc: 0.8370 - 39ms/epoch - 10ms/step
# Epoch 12/30
# 4/4 - 0s - loss: 0.9365 - accuracy: 0.6331 - auc: 0.9191 - val_loss: 1.2342 - val_accuracy: 0.4399 - val_auc: 0.8388 - 38ms/epoch - 10ms/step
# Epoch 13/30
# 4/4 - 0s - loss: 0.9124 - accuracy: 0.6486 - auc: 0.9247 - val_loss: 1.2268 - val_accuracy: 0.4419 - val_auc: 0.8407 - 44ms/epoch - 11ms/step
# Epoch 14/30
# 4/4 - 0s - loss: 0.8885 - accuracy: 0.6563 - auc: 0.9302 - val_loss: 1.2213 - val_accuracy: 0.4477 - val_auc: 0.8426 - 41ms/epoch - 10ms/step
# Epoch 15/30
# 4/4 - 0s - loss: 0.8659 - accuracy: 0.6654 - auc: 0.9334 - val_loss: 1.2189 - val_accuracy: 0.4593 - val_auc: 0.8440 - 40ms/epoch - 10ms/step
# Epoch 16/30
# 4/4 - 0s - loss: 0.8449 - accuracy: 0.6757 - auc: 0.9369 - val_loss: 1.2143 - val_accuracy: 0.4554 - val_auc: 0.8451 - 43ms/epoch - 11ms/step
# Epoch 17/30
# 4/4 - 0s - loss: 0.8231 - accuracy: 0.6880 - auc: 0.9414 - val_loss: 1.2138 - val_accuracy: 0.4709 - val_auc: 0.8453 - 42ms/epoch - 11ms/step
# Epoch 18/30
# 4/4 - 0s - loss: 0.8017 - accuracy: 0.6990 - auc: 0.9452 - val_loss: 1.2179 - val_accuracy: 0.4729 - val_auc: 0.8448 - 43ms/epoch - 11ms/step
# Epoch 19/30
# 4/4 - 0s - loss: 0.7833 - accuracy: 0.7151 - auc: 0.9487 - val_loss: 1.2192 - val_accuracy: 0.4651 - val_auc: 0.8446 - 44ms/epoch - 11ms/step
# Epoch 20/30
# 4/4 - 0s - loss: 0.7633 - accuracy: 0.7326 - auc: 0.9529 - val_loss: 1.2191 - val_accuracy: 0.4690 - val_auc: 0.8452 - 44ms/epoch - 11ms/step
# Epoch 21/30
# 4/4 - 0s - loss: 0.7435 - accuracy: 0.7468 - auc: 0.9567 - val_loss: 1.2255 - val_accuracy: 0.4826 - val_auc: 0.8444 - 41ms/epoch - 10ms/step
# Epoch 22/30
# 4/4 - 0s - loss: 0.7267 - accuracy: 0.7416 - auc: 0.9590 - val_loss: 1.2296 - val_accuracy: 0.4845 - val_auc: 0.8449 - 42ms/epoch - 10ms/step
# Epoch 23/30
# 4/4 - 0s - loss: 0.7068 - accuracy: 0.7500 - auc: 0.9613 - val_loss: 1.2328 - val_accuracy: 0.4767 - val_auc: 0.8455 - 42ms/epoch - 10ms/step
# Epoch 24/30
# 4/4 - 0s - loss: 0.6874 - accuracy: 0.7616 - auc: 0.9629 - val_loss: 1.2384 - val_accuracy: 0.4767 - val_auc: 0.8451 - 42ms/epoch - 11ms/step
# Epoch 25/30
# 4/4 - 0s - loss: 0.6706 - accuracy: 0.7681 - auc: 0.9642 - val_loss: 1.2451 - val_accuracy: 0.4748 - val_auc: 0.8451 - 42ms/epoch - 10ms/step
# Epoch 26/30
# 4/4 - 0s - loss: 0.6546 - accuracy: 0.7707 - auc: 0.9657 - val_loss: 1.2540 - val_accuracy: 0.4884 - val_auc: 0.8440 - 45ms/epoch - 11ms/step
# Epoch 27/30
# 4/4 - 0s - loss: 0.6388 - accuracy: 0.7765 - auc: 0.9677 - val_loss: 1.2578 - val_accuracy: 0.4767 - val_auc: 0.8435 - 45ms/epoch - 11ms/step
# Epoch 28/30
# 4/4 - 0s - loss: 0.6190 - accuracy: 0.7920 - auc: 0.9716 - val_loss: 1.2595 - val_accuracy: 0.4535 - val_auc: 0.8426 - 41ms/epoch - 10ms/step
# Epoch 29/30
# 4/4 - 0s - loss: 0.6028 - accuracy: 0.8107 - auc: 0.9754 - val_loss: 1.2715 - val_accuracy: 0.4419 - val_auc: 0.8407 - 45ms/epoch - 11ms/step
# Epoch 30/30
# 4/4 - 0s - loss: 0.5935 - accuracy: 0.8204 - auc: 0.9764 - val_loss: 1.2746 - val_accuracy: 0.4593 - val_auc: 0.8417 - 45ms/epoch - 11ms/step

# %% [markdown]
# ### Neural Network on Principal Components

# %%
## Your Answer Here

# %% [markdown]
# ### Neural Network on Principal Components + Cluster Membership

# %%
## Your Answer Here

# %% [markdown]
# ## Discussion Questions

# %% [markdown]
# 1. In your own words, what is the difference between PCA and clustering?

# %% [markdown]
# ## Your Answer Here

# %% [markdown]
# 2. Did you notice any advantages to combining PCA and clustering? If so, what do you think they were? If not, why do you think you didn't see any gains from this combination?

# %% [markdown]
# ## Your Answer Here

# %% [markdown]
# 3. How can unsupervised techniques help with downstream supervised learning tasks when working with "big data?"
